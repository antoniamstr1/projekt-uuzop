# %% [markdown]
# # Replikacija podataka

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#assessments = pd.read_csv("anonymisedData/assessments.csv")
#courses = pd.read_csv("anonymisedData/courses.csv")
studentAssessment = pd.read_csv("anonymisedData/studentAssessment.csv")
studentInfo = pd.read_csv("anonymisedData/studentInfo.csv")
studentRegistration = pd.read_csv("anonymisedData/studentRegistration.csv")
studentVle = pd.read_csv("anonymisedData/studentVle.csv")
#vle = pd.read_csv("anonymisedData/vle.csv")

# %% [markdown]
# #### Fig. 1. Number of students in 4 categories: Withdrawn, Failed, Pass, Distinction

# %%
result = studentInfo['final_result'].unique()

result_count = studentInfo['final_result'].value_counts()

#sorted_result_count = result_count.sort_index()
#sorted_result = sorted(result)
custom_order = ['Distinction','Pass','Fail','Withdrawn']
sorted_result_count = result_count.loc[custom_order]

colors=['#e8bf1c','#4882bd','#178f0e','#5c1682']

fig, ax = plt.subplots()

right_side = ax.spines["right"]
right_side.set_visible(False)
left_side = ax.spines["left"]
left_side.set_visible(False)
top_side = ax.spines["top"]
top_side.set_visible(False)
bottom_side = ax.spines["bottom"]
bottom_side.set_visible(False)


plt.grid(axis='x', 
         zorder=0)
plt.barh(sorted_result_count.index, 
         sorted_result_count,
         color=colors, 
         height=0.3, 
         zorder = 5)

#text labels

plt.show()

# %% [markdown]
# #### Table 2. Pearson’s Correlation test result

# %% [markdown]
# pokušaj sa djelomičnim tablicama

# %%
merged_studentInfo_studentAssessment = pd.merge(studentInfo, studentAssessment, on='id_student')
merged_studentInfo_studentAssessment.dropna(inplace=True)

merged_studentInfo_studentRegistration = pd.merge(studentInfo, studentRegistration, on='id_student')
merged_studentInfo_studentRegistration.dropna(inplace=True)

merged_studentInfo_studentVle = pd.merge(studentInfo, studentVle, on='id_student')
merged_studentInfo_studentVle.dropna(inplace=True)

merged_studentRegistration_studentVle = pd.merge(studentRegistration, studentVle, on='id_student')
merged_studentRegistration_studentVle.dropna(inplace=True)

merged_studentAssessment_studentVle = pd.merge(studentAssessment, studentVle, on='id_student')
merged_studentAssessment_studentVle.dropna(inplace=True)

merged_studentRegistration_studentAssessment = pd.merge(studentRegistration, studentAssessment, on='id_student')
merged_studentRegistration_studentAssessment.dropna(inplace=True)

#1.30

# %%
from scipy.stats import pearsonr
from sklearn import preprocessing 

merged_list = ['merged_studentInfo_studentAssessment','merged_studentInfo_studentRegistration',
               'merged_studentInfo_studentVle','merged_studentRegistration_studentVle',
               'merged_studentAssessment_studentVle','merged_studentRegistration_studentAssessment']
merged_list_notdef = [merged_studentInfo_studentAssessment,merged_studentInfo_studentRegistration,
               merged_studentInfo_studentVle,merged_studentRegistration_studentVle,
               merged_studentAssessment_studentVle,merged_studentRegistration_studentAssessment]
rows_csv = {"Gender" : "studentInfo", 
        "Educational Level" : "studentInfo", 
        "Age": "studentInfo", 
        "Previous Attempts": "studentInfo",
          "Disability": "studentInfo",
          "First Assig.Mark": "studentAssessment", 
          "Registration Date": "studentRegistration" ,
          "Clicks till Course Start": "studentVle"}
rows_csv_notdef = {"Gender" : studentInfo, 
        "Educational Level" : studentInfo, 
        "Age": studentInfo, 
        "Previous Attempts": studentInfo,
          "Disability": studentInfo,
          "First Assig.Mark": studentAssessment, 
          "Registration Date": studentRegistration ,
          "Clicks till Course Start": studentVle}
atributes = {"Gender" : "gender", 
        "Educational Level" : "highest_education", 
        "Age": "age_band", 
        "Previous Attempts": "num_of_prev_attempts",
          "Disability": "disability",
          "First Assig.Mark": "score", 
          "Registration Date": "date_registration" ,
          "Clicks till Course Start": "sum_click"}
#table
rows = ["Gender", "Educational Level", "Age", "Previous Attempts",
          "Disability", "First Assig.Mark", "Registration Date" ,"Clicks till Course Start"]
table_data = []
table_rows = ["", "Gender", "Educational Level", "Age", "Previous Attempts",
          "Disability", "First Assig.Mark", "Registration Date" ,"Clicks till Course Start"]
table_data.append(table_rows)

for r1 in range(0,len(rows)):
    tab_redak = []
    tab_redak.append(rows[r1])
    for r2 in range(0,len(rows)):
        #print('gledam za ' + rows[r1] + ' i ' +rows[r2] )
        row = rows[r1]  #ime prvog elementa
        column = rows[r2] #ime drugog elementa
        table_row = rows_csv[row] #u kojoj je tablici e1
        table_column = rows_csv[column] #u kojoj je tablici e2
        
        for naziv in merged_list:
            #print(table_row, table_column)
            #print('naziv:', naziv)
            if (table_row in naziv and table_column in naziv):
                #dobijem naziv atributa u tablici
                
                
                atr1 = atributes[row]
                atr2 = atributes[column]
                
                #print('atributi:',atr1, atr2)
                index = merged_list.index(naziv)
                #dobijem naziv tablice
                naziv_notdef = merged_list_notdef[index]
                #ako su tipovi atribuita object onda, label
                if atr1 == atr2:
                    naziv_notdef = rows_csv_notdef[row]
                    naziv_notdef.dropna(inplace=True)

                    
                list1 = naziv_notdef[atr1]
                list2 = naziv_notdef[atr2]
                label_encoder = preprocessing.LabelEncoder() 
                
                if (naziv_notdef[atr1].dtype == "object"):
                    #print('label encoder 1')
                    list1 = label_encoder.fit_transform(list1) 
                
                if (naziv_notdef[atr2].dtype == "object"):
                    #print('label encoder 2')
                    list2 = label_encoder.fit_transform(list2) 
                
                #list1 = [x for x in list1 if not np.isnan(x)]
                #list2 = [x for x in list2 if not np.isnan(x)]

                corr, _ = pearsonr(list1, list2)
                tab_redak.append( round(corr, 2))
                #print('corr:',corr)
                break
    #print('tab_redak:', tab_redak)
    table_data.append(tab_redak)
    tab_redak = []
    
#30s

del merged_studentInfo_studentAssessment
del merged_studentInfo_studentRegistration
del merged_studentInfo_studentVle
del merged_studentRegistration_studentVle
del merged_studentAssessment_studentVle
del merged_studentRegistration_studentAssessment

# %%
#ispis tablice
fig, ax = plt.subplots(figsize=(12, 6))

# Hide axes
ax.axis('off')

# Create the table
table = ax.table(cellText=table_data, loc='center', cellLoc='center', colLabels=None)

# Optionally, format the table
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

plt.show()

# %% [markdown]
# pokušaj sa cijelom tablicom samo sa određenim podatcima

# %%
columns_studentInfo = ['id_student','gender', 'age_band', 'disability', 'num_of_prev_attempts', 'highest_education']
columns_studentAssessment = ['id_student','score']
columns_studentRegistration = ['id_student','date_registration']
columns_studentVle = [ 'id_student','sum_click']


# Merge DataFrames
merged_table = pd.merge(studentInfo[columns_studentInfo],
                        studentAssessment[columns_studentAssessment],
                        on='id_student',
                        how='inner')

merged_table = pd.merge(merged_table,
                        studentRegistration[columns_studentRegistration],
                        on='id_student',
                        how='inner')

merged_table = pd.merge(merged_table,
                        studentVle[columns_studentVle],
                        on='id_student',
                        how='inner')

merged_table.dropna(inplace=True)


# 10s

# %%
from scipy.stats import pearsonr
from sklearn import preprocessing 

rows_csv = {"Gender" : "studentInfo", 
        "Educational Level" : "studentInfo", 
        "Age": "studentInfo", 
        "Previous Attempts": "studentInfo",
          "Disability": "studentInfo",
          "First Assig.Mark": "studentAssessment", 
          "Registration Date": "studentRegistration" ,
          "Clicks till Course Start": "studentVle"}

atributes = {"Gender" : "gender", 
        "Educational Level" : "highest_education", 
        "Age": "age_band", 
        "Previous Attempts": "num_of_prev_attempts",
          "Disability": "disability",
          "First Assig.Mark": "score", 
          "Registration Date": "date_registration" ,
          "Clicks till Course Start": "sum_click"}
#table
rows = ["Gender", "Educational Level", "Age", "Previous Attempts",
          "Disability", "First Assig.Mark", "Registration Date" ,"Clicks till Course Start"]
table_data = []
table_rows = ["", "Gender", "Educational Level", "Age", "Previous Attempts",
          "Disability", "First Assig.Mark", "Registration Date" ,"Clicks till Course Start"]
table_data.append(table_rows)

for r1 in range(0,len(rows)):
    tab_redak = []
    tab_redak.append(rows[r1])
    for r2 in range(0,len(rows)):
        print('gledam za ' + rows[r1] + ' i ' +rows[r2] )
        row = rows[r1]  #ime prvog elementa
        column = rows[r2] #ime drugog elementa
        table_row = rows_csv[row] #u kojoj je tablici e1
        table_column = rows_csv[column] #u kojoj je tablici e2
        
                
        atr1 = atributes[row]
        atr2 = atributes[column]
        print('atributi:', atr1, atr2)      
        list1 = merged_table[atr1]
        list2 = merged_table[atr2]
        label_encoder = preprocessing.LabelEncoder() 
                
        if (merged_table[atr1].dtype == "object"):
                    print('label encoder 1')
                    list1 = label_encoder.fit_transform(list1) 
                
        if (merged_table[atr2].dtype == "object"):
                    print('label encoder 2')
                    list2 = label_encoder.fit_transform(list2) 
                
                

        corr, _ = pearsonr(list1, list2)
        tab_redak.append( round(corr, 2))
        print('corr:',corr)
                
    #print('tab_redak:', tab_redak)
    table_data.append(tab_redak)
    
del merged_table
# 6min 21s
# Out:
# gledam za Gender i Gender
# atributi: gender gender
# label encoder 1
# label encoder 2
# corr: 1.0
# gledam za Gender i Educational Level
# atributi: gender highest_education
# label encoder 1
# label encoder 2
# corr: 0.021495389112293768
# gledam za Gender i Age
# atributi: gender age_band
# label encoder 1
# label encoder 2
# corr: 0.058088751069824536
# gledam za Gender i Previous Attempts
# atributi: gender num_of_prev_attempts
# label encoder 1
# corr: -0.02894574649646954
# gledam za Gender i Disability
# atributi: gender disability
# label encoder 1
# label encoder 2
# corr: -0.010082877835534684
# gledam za Gender i First Assig.Mark
# atributi: gender score
# label encoder 1
# corr: -0.011453348763078668
# gledam za Gender i Registration Date
# atributi: gender date_registration
# label encoder 1
# corr: -0.034935735211124974
# gledam za Gender i Clicks till Course Start
# atributi: gender sum_click
# label encoder 1
# corr: 0.018609002923514435
# gledam za Educational Level i Gender
# atributi: highest_education gender
# label encoder 1
# label encoder 2
# corr: 0.021495389112293768
# gledam za Educational Level i Educational Level
# atributi: highest_education highest_education
# label encoder 1
# label encoder 2
# corr: 0.99999999996598
# gledam za Educational Level i Age
# atributi: highest_education age_band
# label encoder 1
# label encoder 2
# corr: 0.10938953719625616
# gledam za Educational Level i Previous Attempts
# atributi: highest_education num_of_prev_attempts
# label encoder 1
# corr: 0.031921162139414164
# gledam za Educational Level i Disability
# atributi: highest_education disability
# label encoder 1
# label encoder 2
# corr: -0.04173814038609142
# gledam za Educational Level i First Assig.Mark
# atributi: highest_education score
# label encoder 1
# corr: -0.030763581302563986
# gledam za Educational Level i Registration Date
# atributi: highest_education date_registration
# label encoder 1
# corr: -0.08421637197046707
# gledam za Educational Level i Clicks till Course Start
# atributi: highest_education sum_click
# label encoder 1
# corr: -0.000717525088801007
# gledam za Age i Gender
# atributi: age_band gender
# label encoder 1
# label encoder 2
# corr: 0.058088751069824536
# gledam za Age i Educational Level
# atributi: age_band highest_education
# label encoder 1
# label encoder 2
# corr: 0.10938953719625616
# gledam za Age i Age
# atributi: age_band age_band
# label encoder 1
# label encoder 2
# corr: 0.9999999999839397
# gledam za Age i Previous Attempts
# atributi: age_band num_of_prev_attempts
# label encoder 1
# corr: 0.056232261097762366
# gledam za Age i Disability
# atributi: age_band disability
# label encoder 1
# label encoder 2
# corr: -0.00709492439422677
# gledam za Age i First Assig.Mark
# atributi: age_band score
# label encoder 1
# corr: 0.02763165931978147
# gledam za Age i Registration Date
# atributi: age_band date_registration
# label encoder 1
# corr: -0.026576001948789504
# gledam za Age i Clicks till Course Start
# atributi: age_band sum_click
# label encoder 1
# corr: 0.00479438347880164
# gledam za Previous Attempts i Gender
# atributi: num_of_prev_attempts gender
# label encoder 2
# corr: -0.02894574649646954
# gledam za Previous Attempts i Educational Level
# atributi: num_of_prev_attempts highest_education
# label encoder 2
# corr: 0.031921162139414164
# gledam za Previous Attempts i Age
# atributi: num_of_prev_attempts age_band
# label encoder 2
# corr: 0.056232261097762366
# gledam za Previous Attempts i Previous Attempts
# atributi: num_of_prev_attempts num_of_prev_attempts
# corr: 1.0
# gledam za Previous Attempts i Disability
# atributi: num_of_prev_attempts disability
# label encoder 2
# corr: 0.09707714206894216
# gledam za Previous Attempts i First Assig.Mark
# atributi: num_of_prev_attempts score
# corr: -0.03413254424252362
# gledam za Previous Attempts i Registration Date
# atributi: num_of_prev_attempts date_registration
# corr: 0.045262217145485
# gledam za Previous Attempts i Clicks till Course Start
# atributi: num_of_prev_attempts sum_click
# corr: -0.0030263408799455025
# gledam za Disability i Gender
# atributi: disability gender
# label encoder 1
# label encoder 2
# corr: -0.010082877835534684
# gledam za Disability i Educational Level
# atributi: disability highest_education
# label encoder 1
# label encoder 2
# corr: -0.04173814038609142
# gledam za Disability i Age
# atributi: disability age_band
# label encoder 1
# label encoder 2
# corr: -0.00709492439422677
# gledam za Disability i Previous Attempts
# atributi: disability num_of_prev_attempts
# label encoder 1
# corr: 0.09707714206894216
# gledam za Disability i Disability
# atributi: disability disability
# label encoder 1
# label encoder 2
# corr: 0.9999999999363773
# gledam za Disability i First Assig.Mark
# atributi: disability score
# label encoder 1
# corr: -0.07370145590352413
# gledam za Disability i Registration Date
# atributi: disability date_registration
# label encoder 1
# corr: 0.050390105519866356
# gledam za Disability i Clicks till Course Start
# atributi: disability sum_click
# label encoder 1
# corr: -0.00271419135144011
# gledam za First Assig.Mark i Gender
# atributi: score gender
# label encoder 2
# corr: -0.011453348763078668
# gledam za First Assig.Mark i Educational Level
# atributi: score highest_education
# label encoder 2
# corr: -0.030763581302563986
# gledam za First Assig.Mark i Age
# atributi: score age_band
# label encoder 2
# corr: 0.02763165931978147
# gledam za First Assig.Mark i Previous Attempts
# atributi: score num_of_prev_attempts
# corr: -0.03413254424252362
# gledam za First Assig.Mark i Disability
# atributi: score disability
# label encoder 2
# corr: -0.07370145590352413
# gledam za First Assig.Mark i First Assig.Mark
# atributi: score score
# corr: 0.9999999999948829
# gledam za First Assig.Mark i Registration Date
# atributi: score date_registration
# corr: 0.01588919186637338
# gledam za First Assig.Mark i Clicks till Course Start
# atributi: score sum_click
# corr: 0.019426810074055254
# gledam za Registration Date i Gender
# atributi: date_registration gender
# label encoder 2
# corr: -0.034935735211124974
# gledam za Registration Date i Educational Level
# atributi: date_registration highest_education
# label encoder 2
# corr: -0.08421637197046707
# gledam za Registration Date i Age
# atributi: date_registration age_band
# label encoder 2
# corr: -0.026576001948789504
# gledam za Registration Date i Previous Attempts
# atributi: date_registration num_of_prev_attempts
# corr: 0.045262217145485
# gledam za Registration Date i Disability
# atributi: date_registration disability
# label encoder 2
# corr: 0.050390105519866356
# gledam za Registration Date i First Assig.Mark
# atributi: date_registration score
# corr: 0.01588919186637338
# gledam za Registration Date i Registration Date
# atributi: date_registration date_registration
# corr: 1.0
# gledam za Registration Date i Clicks till Course Start
# atributi: date_registration sum_click
# corr: 0.004571140167905097
# gledam za Clicks till Course Start i Gender
# atributi: sum_click gender
# label encoder 2
# corr: 0.018609002923514435
# gledam za Clicks till Course Start i Educational Level
# atributi: sum_click highest_education
# label encoder 2
# corr: -0.000717525088801007
# gledam za Clicks till Course Start i Age
# atributi: sum_click age_band
# label encoder 2
# corr: 0.00479438347880164
# gledam za Clicks till Course Start i Previous Attempts
# atributi: sum_click num_of_prev_attempts
# corr: -0.0030263408799455025
# gledam za Clicks till Course Start i Disability
# atributi: sum_click disability
# label encoder 2
# corr: -0.00271419135144011
# gledam za Clicks till Course Start i First Assig.Mark
# atributi: sum_click score
# corr: 0.019426810074055254
# gledam za Clicks till Course Start i Registration Date
# atributi: sum_click date_registration
# corr: 0.004571140167905097
# gledam za Clicks till Course Start i Clicks till Course Start
# atributi: sum_click sum_click
# corr: 0.9999999999737487

# %%
#ispis tablice
fig, ax = plt.subplots(figsize=(12, 6))

# Hide axes
ax.axis('off')

# Create the table
table = ax.table(cellText=table_data, loc='center', cellLoc='center', colLabels=None)

# Optionally, format the table
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

plt.show()

# %% [markdown]
# #### Table 3. Performance comparisons between three predictive models

# %% [markdown]
# "The chosen variables for
# the resulting csv file used to train our learning algorithms included the First Assignment
# Mark, Educational Level, Clicks till Course Starts, Registration date, Age, and Gender.
# 70% of the data were used as the training data, and 30% as the test data."

# %%
columns_studentInfo = ['id_student','gender', 'age_band', 'highest_education', 'final_result']
columns_studentAssessment = ['id_student','score']
columns_studentRegistration = ['id_student','date_registration']
columns_studentVle = [ 'id_student','sum_click']

merged_table_2 = pd.merge(studentInfo[columns_studentInfo],
                        studentAssessment[columns_studentAssessment],
                        on='id_student',
                        how='inner')
merged_table_2 = pd.merge(merged_table_2,
                        studentRegistration[columns_studentRegistration],
                        on='id_student',
                        how='inner')
merged_table_2 = pd.merge(merged_table_2,
                        studentVle[columns_studentVle],
                        on='id_student',
                        how='inner')

merged_table_2.dropna(inplace=True)
merged_table_2.drop('id_student',axis=1)

df = pd.DataFrame(merged_table_2)
#df.to_csv('merged_table_2.csv',index=False)


#uzet ću prvih 10 000 redaka
merged_table_2 = df.sample(n=100000, random_state=42)
merged_table_2.to_csv('merged_table_2.csv',index=False)

# %% [markdown]
# DECISION TREE

# %%
# Import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
import pandas as pd
from sklearn import preprocessing 


cm_decision_tree = []
df = pd.DataFrame(merged_table_2)

# Separate features and target variable
label_encoder = preprocessing.LabelEncoder() 
df['gender'] = label_encoder.fit_transform(df['gender']) 
df['age_band'] = label_encoder.fit_transform(df['age_band']) 
df['highest_education'] = label_encoder.fit_transform(df['highest_education']) 

data_decision_tree = {}
def decision_tree(value):
    X = df[['gender',	'age_band',	'highest_education',	'score'	,'date_registration',	'sum_click']]

    #df['final_result'] = label_encoder.fit_transform(df['final_result']) 
    df['binary_target'] = (df['final_result'] == value).astype(int)

    y = df['binary_target']

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Create a decision tree classifier
    clf = DecisionTreeClassifier()

    # Train the classifier on the training data
    clf.fit(X_train, y_train)

    # Make predictions on the testing data
    predictions = clf.predict(X_test)
    print('predictions:',predictions)
    # Evaluate the performance of the model
    accuracy = accuracy_score(y_test, predictions)
    print(f'Accuracy: {accuracy}')

    # Display classification report
    print('Classification Report:')
    print(classification_report(y_test, predictions))
   
    data_decision_tree[value] = [predictions,accuracy, classification_report(y_test, predictions)]

    if value == 'Pass':
        return confusion_matrix(y_test, predictions)
    del X_train, X_test, y_train, y_test, clf




values =['Withdrawn','Fail','Pass','Distinction']
for i in values:
    print('Decision tree -->' + i)
    
    if i == 'Pass':
       cm_decision_tree = decision_tree(i)
    else:
        decision_tree(i)
    

del df    
#8min15s
# Out:
# Decision tree -->Withdrawn
# predictions: [1 1 1 ... 1 1 1]
# Accuracy: 0.6136666666666667
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.55      0.52     11508
#            1       0.70      0.65      0.68     18492
#
#     accuracy                           0.61     30000
#    macro avg       0.60      0.60      0.60     30000
# weighted avg       0.62      0.61      0.62     30000
#
# Decision tree -->Fail
# predictions: [1 0 0 ... 0 0 0]
# Accuracy: 0.9079
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     27522
#            1       0.43      0.33      0.37      2478
#
#     accuracy                           0.91     30000
#    macro avg       0.68      0.65      0.66     30000
# weighted avg       0.90      0.91      0.90     30000
#
# Decision tree -->Pass
# predictions: [0 0 0 ... 0 0 0]
# Accuracy: 0.7342666666666666
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.83     22242
#            1       0.48      0.40      0.43      7758
#
#     accuracy                           0.73     30000
#    macro avg       0.64      0.62      0.63     30000
# weighted avg       0.72      0.73      0.73     30000
#
# Decision tree -->Distinction
# predictions: [0 0 0 ... 0 0 0]
# Accuracy: 0.955
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     28728
#            1       0.46      0.34      0.39      1272
#
#     accuracy                           0.95     30000
#    macro avg       0.72      0.66      0.69     30000
# weighted avg       0.95      0.95      0.95     30000

# %% [markdown]
# RANDOM FOREST

# %%
# Import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd
from sklearn import preprocessing 
from sklearn.metrics import confusion_matrix




df = pd.DataFrame(merged_table_2)
cm_random_forest = []
# Separate features and target variable
label_encoder = preprocessing.LabelEncoder() 
df['gender'] = label_encoder.fit_transform(df['gender']) 
df['age_band'] = label_encoder.fit_transform(df['age_band']) 
df['highest_education'] = label_encoder.fit_transform(df['highest_education']) 

data_random_forest = {}
def random_forest(value):
    X = df[['gender',	'age_band',	'highest_education',	'score'	,'date_registration',	'sum_click']]

    #df['final_result'] = label_encoder.fit_transform(df['final_result']) 
    df['binary_target'] = (df['final_result'] == value).astype(int)

    y = df['binary_target']

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Create a decision tree classifier
    clf = RandomForestClassifier(n_estimators=10, random_state=42)  

    # Train the classifier on the training data
    clf.fit(X_train, y_train)

    # Make predictions on the testing data
    predictions = clf.predict(X_test)

    # Evaluate the performance of the model
    accuracy = accuracy_score(y_test, predictions)
    print(f'Accuracy: {accuracy}')

    # Display classification report
    print('Classification Report:')
    print(classification_report(y_test, predictions))
    
    data_random_forest[value] =[accuracy, classification_report(y_test, predictions)]
    
    if value == 'Pass':
        return confusion_matrix(y_test, predictions)

values =['Withdrawn','Fail','Pass','Distinction']
for i in values:
    print('Random forest -->' + i)
    
    if i == 'Pass':
       cm_random_forest = random_forest(i)
    else:
        random_forest(i)
del df
# Out:
# Random forest -->Withdrawn
# Accuracy: 0.6168666666666667
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.48      0.49     11508
#            1       0.68      0.70      0.69     18492
#
#     accuracy                           0.62     30000
#    macro avg       0.59      0.59      0.59     30000
# weighted avg       0.61      0.62      0.62     30000
#
# Random forest -->Fail
# Accuracy: 0.913
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95     27522
#            1       0.46      0.31      0.37      2478
#
#     accuracy                           0.91     30000
#    macro avg       0.70      0.64      0.66     30000
# weighted avg       0.90      0.91      0.90     30000
#
# Random forest -->Pass
# Accuracy: 0.735
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83     22242
#            1       0.48      0.39      0.43      7758
#
#     accuracy                           0.73     30000
#    macro avg       0.64      0.62      0.63     30000
# weighted avg       0.72      0.73      0.72     30000
#
# Random forest -->Distinction
# Accuracy: 0.9584
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     28728
#            1       0.51      0.35      0.41      1272
#
#     accuracy                           0.96     30000
#    macro avg       0.74      0.67      0.70     30000
# weighted avg       0.95      0.96      0.95     30000

# %% [markdown]
# BART

# %%
# Import necessary libraries
from sklearn.model_selection import train_test_split
from bartpy.sklearnmodel import SklearnModel
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd
from sklearn import preprocessing 


df = pd.DataFrame(merged_table_2)

# Separate features and target variable
label_encoder = preprocessing.LabelEncoder() 
df['gender'] = label_encoder.fit_transform(df['gender']) 
df['age_band'] = label_encoder.fit_transform(df['age_band']) 
df['highest_education'] = label_encoder.fit_transform(df['highest_education']) 

data_bart = {}
def BARTT(value):
    X = df[['gender',	'age_band',	'highest_education',	'score'	,'date_registration',	'sum_click']]

    df['final_result'] = label_encoder.fit_transform(df['final_result']) 
    #df['binary_target'] = (df['final_result'] == value).astype(int)

    y = df['final_result']

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    print(type(X_test))
    # Create a decision tree classifier
    clf = BART(random_state=0, burnin=5, ndraw=5)

    # Train the classifier on the training data
    clf.fit(X_train, y_train)
    predictions = clf.predict(X_test)
    # Make predictions on the testing data
    predictions_binary = [1 if pred > 0.5 else 0 for pred in predictions]

    # Evaluate the performance of the model
    accuracy = accuracy_score(y_test, predictions_binary)
    print(f'Accuracy: {accuracy}')

    # Display classification report
    print('Classification Report:')
    print(classification_report(y_test, predictions_binary))
    data_bart[value] =[accuracy, classification_report(y_test, predictions_binary)]


values =['Withdrawn','Fail','Pass','Distinction']
for i in values:
    print('BART -->' + i)
    BARTT(i)
    
del df
#1min30s
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Import necessary libraries
#       2 from sklearn.model_selection import train_test_split
# ----> 3 from bartpy.sklearnmodel import SklearnModel
#       4 from sklearn.metrics import accuracy_score, classification_report
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'bartpy'

# %% [markdown]
# #### Table 4. Confusion Matrix for Pass versus the rest

# %%
table_data_3 = [
    ['','Pass','Other'],
    ['Pass', cm_decision_tree[0][0],cm_decision_tree[0][1]],
    ['Other', cm_decision_tree[1][0],cm_decision_tree[0][1]],
]

#ispis tablice
fig, ax = plt.subplots(figsize=(8, 3))

ax.axis('off')

table = ax.table(cellText=table_data_3, loc='center', cellLoc='center', colLabels=None)

plt.show()

# %%
table_data_4 = [
    ['','Pass','Other'],
    ['Pass', cm_random_forest[0][0],cm_random_forest[0][1]],
    ['Other', cm_random_forest[1][0],cm_random_forest[0][1]],
]

#ispis tablice
fig, ax = plt.subplots(figsize=(8, 3))

ax.axis('off')

table = ax.table(cellText=table_data_4, loc='center', cellLoc='center', colLabels=None)

plt.show()
